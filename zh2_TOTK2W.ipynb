-- %%
SELECT FOGLALAS_PK,UGYfel_fk,DATEDIFF(day,mettol,meddig)as 'Foglalas időtartam',LAg(DATEDIFF(day,mettol,meddig),1,'Nincs')over(order by UGYfel_fk) as 'Előtte',Lead(DATEDIFF(day,mettol,meddig),1,'Nincs')over(order by UGYfel_fk) as 'Utána'
FROM FOGLALAS
-- Out:
-- Total execution time: 00:00:00.013
-- <table><tr><th>FOGLALAS_PK</th><th>UGYfel_fk</th><th>Foglalas időtartam</th><th>Előtte</th><th>Utána</th></tr></table>
-- : Msg 245, Level 16, State 1, Line 1
-- Conversion failed when converting the varchar value 'Nincs' to data type int.
